# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
# Importing all libraries

import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters

file_path_bitstamp = Path('../Resources/bitstamp.csv')
bitstamp = pd.read_csv(file_path_bitstamp, index_col="Timestamp", parse_dates=True, infer_datetime_format=True)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.

display(bitstamp.head())
display(bitstamp.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# ...

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters

file_path_coinbase = Path("../Resources/coinbase.csv")
coinbase = pd.read_csv(file_path_coinbase, index_col="Timestamp", parse_dates=True, infer_datetime_format=True)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.

display(coinbase.head())
display(coinbase.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame

bitstamp.isnull().sum() # There are 473 missing values for each column
# Out:
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64

# %%
# Dropping the null values using dropna() function

bitstamp.dropna(axis=0, how='any', inplace=True)

# %%
# After dropping the null values, we confirm that that there are no other null values in the dataframe

bitstamp.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $

bitstamp['Close'] = bitstamp['Close'].str.replace('$', '', regex=None)
bitstamp.head()
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_5608\881397283.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bitstamp['Close'] = bitstamp['Close'].str.replace('$', '', regex=None)
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float

bitstamp['Close']=bitstamp['Close'].astype("float")
bitstamp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129067 entries, 2018-01-01 00:00:00 to 2018-03-31 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Open            129067 non-null  float64
#  1   High            129067 non-null  float64
#  2   Low             129067 non-null  float64
#  3   Close           129067 non-null  float64
#  4   BTC Volume      129067 non-null  float64
#  5   USD Volume      129067 non-null  float64
#  6   Weighted Price  129067 non-null  float64
# dtypes: float64(7)
# memory usage: 7.9 MB

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary

bitstamp.duplicated().sum() # No duplicate values in dataframe.
# Out:
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame

# Step 1 - Replace or drop all NaNs or missing values in DataFrame

display(coinbase.isnull().sum()) # There are 218 missing values for each column
# Out:
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64

# %%
# Dropping the null values using dropna() function

coinbase.dropna(axis=0, how="any", inplace=True)

# %%
# After dropping the null values, we confirm that that there are no other null values in the dataframe

display(coinbase.isnull().sum())
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
# Step 2 - Use the str.replace function to remove the dollar sign, $ from "Close" column of Coinbase dataframe

coinbase['Close'] = coinbase['Close'].str.replace('$', '', regex=None)
coinbase.head()
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_5608\3136630185.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coinbase['Close'] = coinbase['Close'].str.replace('$', '', regex=None)
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# ...

# %%
# Step 3 - Convert the data type of "Close" column to a float

coinbase['Close']=coinbase['Close'].astype("float")
coinbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129322 entries, 2018-01-01 00:00:00 to 2018-03-31 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Open            129322 non-null  float64
#  1   High            129322 non-null  float64
#  2   Low             129322 non-null  float64
#  3   Close           129322 non-null  float64
#  4   BTC Volume      129322 non-null  float64
#  5   USD Volume      129322 non-null  float64
#  6   Weighted Price  129322 non-null  float64
# dtypes: float64(7)
# memory usage: 7.9 MB

# %%
# Step 4 - Review the data for duplicate values, and drop them if necessary

coinbase.duplicated().sum() # No duplicate values
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame

bitstamp_sliced = pd.DataFrame(bitstamp.loc[:, 'Close'])

# Review the first five rows of the DataFrame

bitstamp_sliced.head()
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13646.48
# 2018-01-01 00:01:00  13658.75
# 2018-01-01 00:02:00  13610.22
# 2018-01-01 00:03:00  13639.09
# 2018-01-01 00:04:00  13620.00

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame

coinbase_sliced = pd.DataFrame(coinbase.loc[:, 'Close'])

# Review the first five rows of the DataFrame

coinbase_sliced.head()
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13608.49
# 2018-01-01 00:01:00  13601.66
# 2018-01-01 00:02:00  13580.00
# 2018-01-01 00:03:00  13550.34
# 2018-01-01 00:04:00  13583.44

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame

bitstamp_sliced.describe(include="all")
# Out:
#                Close
# count  129067.000000
# mean    10459.842453
# std      2315.976088
# min      5944.000000
# 25%      8613.370000
# 50%     10145.950000
# 75%     11444.810000
# max     17234.980000

# %%
# Generate the summary statistics for the coinbase DataFrame

coinbase_sliced.describe(include="all")
# Out:
#                Close
# count  129322.000000
# mean    10449.140958
# std      2317.197419
# min      5882.310000
# 25%      8609.230000
# 50%     10137.440000
# 75%     11397.237500
# max     17177.990000

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization

bitstamp_sliced.plot(kind="line", figsize=(4,4), title="Closing stock price for full length of time - Bitstamp" , color='blue')
# Out:
# <AxesSubplot:title={'center':'Closing stock price for full length of time - Bitstamp'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization

coinbase_sliced.plot(kind="line", figsize=(4,4), title="Closing stock price for full length of time - Coinbase" , color='orange')
# Out:
# <AxesSubplot:title={'center':'Closing stock price for full length of time - Coinbase'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label

bitstamp_sliced['Close'].plot(legend=True, figsize=(20,20), title="Closing Price for full length of time - Bitstamp vs. Coinbase", color="blue", label="Closing Price - Bitstamp")
coinbase_sliced['Close'].plot(legend=True, figsize=(20,20), color="orange", label="Closing Price - Coinbase")
# Out:
# <AxesSubplot:title={'center':'Closing Price for full length of time - Bitstamp vs. Coinbase'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label

# One month early in the dataset: from 01-January-2018 to 31-January-2018. Overlaying the visualizations

bitstamp_sliced['Close'].loc["2018-01-01":"2018-01-31"].plot(legend=True, figsize=(20,20), title="January Closing Price - Bitstamp vs. Coinbase", color="blue", label="January Closing Price - Bitstamp")
coinbase_sliced['Close'].loc["2018-01-01":"2018-01-31"].plot(legend=True, figsize=(20,20), color="orange", label="January Closing Price - Coinbase")
# Out:
# <AxesSubplot:title={'center':'January Closing Price - Bitstamp vs. Coinbase'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 

# Retrieved data for one month later in the dataset: from 01-March-2018 to 31-March-2018. Overlaying visualizations

bitstamp_sliced['Close'].loc["2018-03-01":"2018-03-31"].plot(legend=True, figsize=(20,20), title="March Closing Price - Bitstamp vs. Coinbase", color="blue", label="March Closing Price - Bitstamp")
coinbase_sliced['Close'].loc["2018-03-01":"2018-03-31"].plot(legend=True, figsize=(20,20), color="orange", label="March Closing Price - Coinbase")
# Out:
# <AxesSubplot:title={'center':'March Closing Price - Bitstamp vs. Coinbase'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** Comparing the visualizations for the periods "01/01/2018-01/31/2018" & "03/01/2018-03/31/2018", we can conclude that the degree of spread has changed over time.
#
# We see price differences between Bitstamp and Coinbase for both periods "01/01/2018-01/31/2018" & "03/01/2018-03/31/2018". Looking at the graphs, we can distinctly see both line graphs (Bitstamp = blue line graph & Coinbase = orange line graph), indicating price differences between the two. Moreover, at times Coinbase appears to be higher priced than Bitstamp. However, to be fully certain about this conclusion, we would need to analyze the data more granularly.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 


# Overlay visualizations: Early one day = 16-January-2018

bitstamp_sliced['Close'].loc["2018-01-16"].plot(legend=True, figsize=(20,20), title="Closing Price Bitstamp vs. Coinbase - January 16, 2018", color="blue", label="Bitstamp closing price: 16-January-2018")
coinbase_sliced['Close'].loc["2018-01-16"].plot(legend=True, figsize=(20,20), color="orange", label="Coinbase closing price: 16-January-2018")
# Out:
# <AxesSubplot:title={'center':'Closing Price Bitstamp vs. Coinbase - January 16, 2018'}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices

# In the previous chart that compares Bitstamp and Coinbase prices for the day 16-January-2018,
# I observe that Coinbase is mostly priced higher than Bitstamp.
# Therefore, my arbitrage strategy is to buy at lower price at Bitstamp and sell it at higher price at Coinbase

arbitrage_spread_early = coinbase_sliced['Close'].loc["2018-01-16"] - bitstamp_sliced['Close'].loc["2018-01-16"]

# Generate summary statistics for the early DataFrame
arbitrage_spread_early.describe()
# Out:
# count    1419.000000
# mean       23.212135
# std        67.789186
# min      -275.920000
# 25%        -8.330000
# 50%        22.280000
# 75%        52.355000
# max       606.800000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot

arbitrage_spread_early.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 

# Overlay visualizations: Middle one day = 24-Febraury-2018

bitstamp_sliced['Close'].loc["2018-02-24"].plot(legend=True, figsize=(20,20), title="Closing Price Bitstamp vs. Coinbase - February 24, 2018", color="blue", label="Bitstamp closing price: 24-February-2018")
coinbase_sliced['Close'].loc["2018-02-24"].plot(legend=True, figsize=(20,20), color="orange", label="Coinbase closing price: 24-February-2018")
# Out:
# <AxesSubplot:title={'center':'Closing Price Bitstamp vs. Coinbase - February 24, 2018'}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices


# In the previous chart that compares Bitstamp and Coinbase prices for the day 24-February-2018,
# I observe that Coinbase is mostly priced higher than Bitstamp, instead of the other way round.
# Therefore, my arbitrage strategy is to buy at lower price at Bitstamp and sell it at higher price at Coinbase

arbitrage_spread_middle = coinbase_sliced['Close'].loc["2018-02-24"] - bitstamp_sliced['Close'].loc["2018-02-24"]

# Generate summary statistics 
arbitrage_spread_middle.describe()
# Out:
# count    1437.000000
# mean        3.396131
# std        22.969472
# min       -50.180000
# 25%       -10.590000
# 50%        -0.010000
# 75%        12.120000
# max       121.320000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot

arbitrage_spread_middle.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 

# Overlay visualizations: Late one day = 10-March-2018

bitstamp_sliced['Close'].loc["2018-03-10"].plot(legend=True, figsize=(20,20), title="Closing Price Bitstamp vs. Coinbase - March 10, 2018", color="blue", label="Bitstamp closing price: 10-March-2018")
coinbase_sliced['Close'].loc["2018-03-10"].plot(legend=True, figsize=(20,20), color="orange", label="Coinbase closing price: 10-March-2018")
# Out:
# <AxesSubplot:title={'center':'Closing Price Bitstamp vs. Coinbase - March 10, 2018'}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices


# In the previous chart that compares Bitstamp and Coinbase prices for the day 10-March-2018,
# I observe that Coinbase is mostly priced higher than Bitstamp.
# Therefore, my arbitrage strategy is to buy at lower price at Bitstamp and sell it at higher price at Coinbase

arbitrage_spread_late = coinbase_sliced['Close'].loc["2018-03-10"] - bitstamp_sliced['Close'].loc["2018-03-10"]

# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
# Out:
# count    1433.000000
# mean        6.541417
# std        15.953638
# min       -36.860000
# 25%        -4.240000
# 50%         7.170000
# 75%        16.040000
# max        93.180000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot


arbitrage_spread_late.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one

# Early date = 16-January-2018

# Use a conditional statement to get a new dataframe that contains only Positive price differences (i.e., where Coinbase price > Bitstamp price)
arbitrage_spread_early_pos = arbitrage_spread_early[arbitrage_spread_early>0]

# Generate summary statistics for arbitrage_spread_early_pos DataFrame
arbitrage_spread_early_pos.describe()
# Out:
# count    960.000000
# mean      53.405344
# std       53.910409
# min        0.010000
# 25%       21.602500
# 50%       39.885000
# 75%       68.547500
# max      606.800000
# Name: Close, dtype: float64

# %%
# Middle date = 24-February-2018

# Use a conditional statement to get a new dataframe that contains only Positive price differences (i.e., where Coinbase price > Bitstamp price)
arbitrage_spread_middle_pos = arbitrage_spread_middle[arbitrage_spread_middle>0]

# Generate summary statistics for arbitrage_spread_middle_pos DataFrame
arbitrage_spread_middle_pos.describe()
# Out:
# count    713.000000
# mean      19.880351
# std       20.699851
# min        0.010000
# 25%        5.040000
# 50%       12.330000
# 75%       27.250000
# max      121.320000
# Name: Close, dtype: float64

# %%
# Late date = 10-March-2018

# Use a conditional statement to get a new dataframe that contains only Positive price differences (i.e., where Coinbase price > Bitstamp price)
arbitrage_spread_late_pos = arbitrage_spread_late[arbitrage_spread_late>0]

# Generate summary statistics for arbitrage_spread_late_pos DataFrame
arbitrage_spread_late_pos.describe()
# Out:
# count    963.000000
# mean      15.001890
# std       11.349685
# min        0.010000
# 25%        7.025000
# 50%       12.660000
# 75%       19.985000
# max       93.180000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).

# I plan to buy in Coinbase and sell in Bitstamp

# Early date = 16-January-2018
spread_return_early = (arbitrage_spread_early_pos)/bitstamp_sliced['Close'].loc["2018-01-16"]

# Review the spread return DataFrame
spread_return_early

# I observed that there were several Null values in the spread_return_early dataframe
# because the dates were different between arbitrage_spread_early_pos dataset and bitstamp_sliced['Close'] dataset.
# Therefore, I dropped the null values using dropna() function

spread_return_early.dropna(axis=0, how="any", inplace=True)

# Review spread_return_early to make sure there are no null values
display(spread_return_early)
# Out:
# Timestamp
# 2018-01-16 00:02:00    0.000731
# 2018-01-16 00:03:00    0.001108
# 2018-01-16 00:04:00    0.000909
# 2018-01-16 00:05:00    0.002485
# 2018-01-16 00:06:00    0.001665
#                          ...
# 2018-01-16 23:47:00    0.005847
# 2018-01-16 23:49:00    0.000921
# 2018-01-16 23:50:00    0.004076
# 2018-01-16 23:55:00    0.000546
# 2018-01-16 23:57:00    0.002153
# Name: Close, Length: 960, dtype: float64

# %%
# Middle date = 24-February-2018

spread_return_middle = arbitrage_spread_middle_pos/bitstamp_sliced['Close'].loc["2018-02-24"]

# Review the spread return DataFrame
spread_return_middle

# I observed that there were several Null values in the spread_return_middle dataframe
# because the dates were different between arbitrage_spread_middle_pos dataset and bitstamp_sliced['Close'] dataset.
# Therefore, I dropped the null values using dropna() function
spread_return_middle.dropna(axis=0, how="any", inplace=True)

# Review spread_return_middle to make sure there are no null values
display(spread_return_middle)
# Out:
# Timestamp
# 2018-02-24 00:10:00    0.000123
# 2018-02-24 00:27:00    0.000189
# 2018-02-24 00:28:00    0.000487
# 2018-02-24 01:23:00    0.000574
# 2018-02-24 01:24:00    0.000163
#                          ...
# 2018-02-24 23:20:00    0.000253
# 2018-02-24 23:47:00    0.000179
# 2018-02-24 23:48:00    0.000846
# 2018-02-24 23:49:00    0.000663
# 2018-02-24 23:51:00    0.000178
# Name: Close, Length: 713, dtype: float64

# %%
# Late date = 10-March-2018

spread_return_late = arbitrage_spread_late_pos/bitstamp_sliced['Close'].loc["2018-03-10"]

# Review the spread return DataFrame

spread_return_late

# I observed that there were several Null values in the spread_return_late dataframe
# because the dates were different between arbitrage_spread_late_pos dataset and bitstamp_sliced['Close'] dataset.
# Therefore, I dropped the null values using dropna() function

spread_return_late.dropna(axis=0, how="any", inplace=True)

# Review spread_return_late to make sure there are no null values
display(spread_return_late)
# Out:
# Timestamp
# 2018-03-10 00:00:00    0.000631
# 2018-03-10 00:06:00    0.000502
# 2018-03-10 00:08:00    0.000793
# 2018-03-10 00:18:00    0.001732
# 2018-03-10 00:19:00    0.000813
#                          ...
# 2018-03-10 23:55:00    0.003054
# 2018-03-10 23:56:00    0.003422
# 2018-03-10 23:57:00    0.001935
# 2018-03-10 23:58:00    0.002236
# 2018-03-10 23:59:00    0.002031
# Name: Close, Length: 963, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs

# Date early in the dataset = 16-January-2018
profitable_trades_early = spread_return_early[spread_return_early>0.01]

# Review the first five profitable trades
profitable_trades_early.head()
# Out:
# Timestamp
# 2018-01-16 02:56:00    0.012962
# 2018-01-16 02:57:00    0.010838
# 2018-01-16 02:59:00    0.014171
# 2018-01-16 03:00:00    0.010675
# 2018-01-16 03:06:00    0.019704
# Name: Close, dtype: float64

# %%
# Date in the middle of dataset = 24-February-2018

profitable_trades_middle = spread_return_middle[spread_return_middle>0.01]

# Review the profitable trades
profitable_trades_middle
# Out:
# Timestamp
# 2018-02-24 08:32:00    0.012726
# 2018-02-24 09:32:00    0.010974
# 2018-02-24 09:39:00    0.010431
# Name: Close, dtype: float64

# %%
# Date in the middle of dataset = 10-March-2018

profitable_trades_late = spread_return_late[spread_return_late>0.01]

# Review the profitable trades
profitable_trades_late
# Out:
# Timestamp
# 2018-03-10 19:04:00    0.010801
# Name: Close, dtype: float64

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%


# Early date = 16-January-2018
profitable_trades_early.describe()
# Out:
# count    73.000000
# mean      0.016720
# std       0.007628
# min       0.010109
# 25%       0.012061
# 50%       0.014794
# 75%       0.018124
# max       0.051633
# Name: Close, dtype: float64

# %%
# Middle date = 24-February-2018

profitable_trades_middle.describe()
# Out:
# count    3.000000
# mean     0.011377
# std      0.001199
# min      0.010431
# 25%      0.010703
# 50%      0.010974
# 75%      0.011850
# max      0.012726
# Name: Close, dtype: float64

# %%
# Late date = 10-March-2018

profitable_trades_late.describe()
# Out:
# count    1.000000
# mean     0.010801
# std           NaN
# min      0.010801
# 25%      0.010801
# 50%      0.010801
# 75%      0.010801
# max      0.010801
# Name: Close, dtype: float64

# %% [markdown]
# How do the average returns compare among the three dates? - The average returns are quite similar for the three dates, between 1% and 1.6%.

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

# Early date = 16-January-2018
profit_early= profitable_trades_early * bitstamp_sliced['Close'].loc["2018-01-16"]

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna(axis=0, how="any")

# View the early profit DataFrame
profit_per_trade_early
# Out:
# Timestamp
# 2018-01-16 02:56:00    162.01
# 2018-01-16 02:57:00    135.00
# 2018-01-16 02:59:00    176.13
# 2018-01-16 03:00:00    134.01
# 2018-01-16 03:06:00    241.54
#                         ...
# 2018-01-16 19:23:00    125.09
# 2018-01-16 19:26:00    131.78
# 2018-01-16 19:38:00    124.01
# 2018-01-16 19:48:00    117.63
# 2018-01-16 20:07:00    113.69
# Name: Close, Length: 73, dtype: float64

# %%
# Middle date = 24-February-2018
profit_middle = profitable_trades_middle * bitstamp_sliced['Close'].loc["2018-02-24"]

# Drop any missing values from the profit DataFrame
profit_per_trade_middle = profit_middle.dropna(axis=0, how="any")

# View the early profit DataFrame
profit_per_trade_middle
# Out:
# Timestamp
# 2018-02-24 08:32:00    121.32
# 2018-02-24 09:32:00    107.00
# 2018-02-24 09:39:00    101.75
# Name: Close, dtype: float64

# %%
# Late date = 10-March-2018
profit_late = profitable_trades_late * bitstamp_sliced['Close'].loc["2018-03-10"]

# Drop any missing values from the profit DataFrame
profit_per_trade_late = profit_late.dropna(axis=0, how="any")

# View the early profit DataFrame
profit_per_trade_late
# Out:
# Timestamp
# 2018-03-10 19:04:00    93.18
# Name: Close, dtype: float64

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame

# Early date = 16-January-2018 - Summary statistics
profit_per_trade_early.describe()
# Out:
# count     73.000000
# mean     193.796849
# std       88.701429
# min      112.520000
# 25%      139.420000
# 50%      171.310000
# 75%      210.060000
# max      606.800000
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame

# Early date = 16-January-2018 - Plot
profit_per_trade_early.plot(kind="line", figsize=(10,7), color="purple")
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Middle date = 24-February-2018 - Summary statistics

profit_per_trade_middle.describe()
# Out:
# count      3.000000
# mean     110.023333
# std       10.129246
# min      101.750000
# 25%      104.375000
# 50%      107.000000
# 75%      114.160000
# max      121.320000
# Name: Close, dtype: float64

# %%
# Middle date = 24-February-2018 - Plot

profit_per_trade_middle.plot(kind="line", figsize=(10,7), color="olive")
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Late date = 10 March 2018 - Summary statistics

profit_per_trade_late.describe()
# Out:
# count     1.00
# mean     93.18
# std        NaN
# min      93.18
# 25%      93.18
# 50%      93.18
# 75%      93.18
# max      93.18
# Name: Close, dtype: float64

# %%
# Late date = 10 March 2018 - Plot

profit_per_trade_late.plot(kind="hist", figsize=(7, 5), color="midnightblue", width=0.1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# For the date late in the dataset, 10-March-2018, only one profitable trade was possible. Therefore, I used histogram instead of line chart to plot the profit made on the trade.

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame

# Early date = 16-January-2018

profit_early_sum = profit_per_trade_early.sum()
print(f"The total profit made on 16-January-2018 is: ${profit_early_sum:.2f}")
# Out:
# The total profit made on 16-January-2018 is: $14147.17

# %%
# Middle date = 24-February-2018

profit_middle_sum = profit_per_trade_middle.sum()
print(f"The total profit made on 24-February-2018 is: ${profit_middle_sum:.2f}")
# Out:
# The total profit made on 24-February-2018 is: $330.07

# %%
# Late date = 10-March-2018

profit_late_sum = profit_per_trade_late.sum()
print(f"The total profit made on 10-March-2018 is: ${profit_late_sum:.2f}")
# Out:
# The total profit made on 10-March-2018 is: $93.18

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame

# Early date = 16-January-2018
cumulative_profit_early = profit_per_trade_early.cumsum()

# %%
# Middle date = 24-February-2018
cumulative_profit_middle = profit_per_trade_middle.cumsum()
cumulative_profit_middle
# Out:
# Timestamp
# 2018-02-24 08:32:00    121.32
# 2018-02-24 09:32:00    228.32
# 2018-02-24 09:39:00    330.07
# Name: Close, dtype: float64

# %%
# Late date = 10-March-2018
cumulative_profit_late = profit_per_trade_late.cumsum()
cumulative_profit_late
# Out:
# Timestamp
# 2018-03-10 19:04:00    93.18
# Name: Close, dtype: float64

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame

# Early date = 16-January-2018
cumulative_profit_early.plot(kind="line", figsize=(10,7), color="purple")
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Middle date = 24-February-2018
cumulative_profit_middle.plot(kind="line", figsize=(10,7), color="olive")
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Late date = 10-March-2018
cumulative_profit_late.plot(kind="hist", figsize=(10,7), color="midnightblue")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Total 3-day profit

total_three_day_profit = profit_early_sum + profit_middle_sum + profit_late_sum
print(f"Total profit for all three days is ${total_three_day_profit: .2f}")
# Out:
# Total profit for all three days is $ 14570.42

# %% [markdown]
# For the date late in the dataset, 10-March-2018, only one profitable trade was possible. Therefore, I used histogram instead of line chart to plot the profit made on the trade.

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Based on my analysis, I observed that there were more opportunities for making arbitrage profits early in Janurary than in February or March. In January, I found 73 opportunities to make profitable arbitrage trade in a single day (16-January-2018). Whereas I found only three such opportunities in s single day in February (24-February-2018) and only one opportunity in a single day in March (10-March-2018).
